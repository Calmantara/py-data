# %%
# Inferential Statistic
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import Math, Latex
from IPython.core.display import Image

# %%
import seaborn as sns
sns.set(color_codes=True)
sns.set(rc={'figure.figsize':(5,5)})

# %%
# Uniform Distribution
from scipy.stats import uniform
n= 10000
start = 10
width = 20
data_uniform = uniform.rvs(size=n, loc=start, scale=width)

# %%
ax = sns.distplot(data_uniform, 
                  bins=100, 
                  kde=True, 
                  color="skyblue", 
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel="Uniform Distribution", ylabel="freq")
# Out:
# /var/folders/vv/qw6j8x591439gjsmtqqfmjw80000gn/T/ipykernel_29980/1050881076.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(data_uniform,
# [Text(0.5, 0, 'Uniform Distribution'), Text(0, 0.5, 'freq')]

# %%
# Distribusi Normal
from scipy.stats import norm
data_normal = norm.rvs(size = 10000, loc = 0, scale = 1)

# %%
data_normal.max()
# Out:
# 3.3706895131220254

# %%
ax = sns.distplot(data_normal,
                 bins=100,
                 kde=True,
                 color="skyblue",
                 hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel = "Normal Distribution", ylabel="freq")
# Out:
# /var/folders/vv/qw6j8x591439gjsmtqqfmjw80000gn/T/ipykernel_29980/2855911883.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(data_normal,
# [Text(0.5, 0, 'Normal Distribution'), Text(0, 0.5, 'freq')]

# %%
# Binomial Distribution
from scipy.stats import binom
data_binom = binom.rvs(n=10,p=0.8,size=10000)
ax = sns.distplot(data_binom,
                  kde=False,
                  color='skyblue',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Binomial Distribution', ylabel='Frequency')
# Out:
# /var/folders/vv/qw6j8x591439gjsmtqqfmjw80000gn/T/ipykernel_29980/2152255114.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(data_binom,
# [Text(0.5, 0, 'Binomial Distribution'), Text(0, 0.5, 'Frequency')]

# %%
from scipy.stats import binom
data_binom = binom.rvs(n=10,p=0.2,size=10000)
ax = sns.distplot(data_binom,
                  kde=False,
                  color='skyblue',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Binomial Distribution', ylabel='Frequency')
# Out:
# /var/folders/vv/qw6j8x591439gjsmtqqfmjw80000gn/T/ipykernel_29980/630828894.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(data_binom,
# [Text(0.5, 0, 'Binomial Distribution'), Text(0, 0.5, 'Frequency')]

# %%
# Bernauli
from scipy.stats import bernoulli
data_bern = bernoulli.rvs(size=10000,p=0.8)
ax= sns.distplot(data_bern,
                 kde=False,
                 color="skyblue",
                 hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Bernoulli Distribution', ylabel='Frequency')
data_bern
# Out:
# /var/folders/vv/qw6j8x591439gjsmtqqfmjw80000gn/T/ipykernel_29980/153435577.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(data_bern,
# array([1, 1, 0, ..., 0, 1, 1])

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df["sex_symbol"] = df.sex.replace({1: "male", 0:"female"})

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target sex_symbol
# 0   2     3       0       male
# 1   0     3       0       male
# 2   0     3       0       male
# 3   1     3       0       male
# 4   3     2       0     female

# %%
df_filtered = df[["target", "sex_symbol"]].dropna()

# %%
df_filtered.head()
# Out:
#    target sex_symbol
# 0       0       male
# 1       0       male
# 2       0       male
# 3       0       male
# 4       0     female

# %%
df_filtered[df_filtered["target"] == 1]
# Out:
#       target sex_symbol
# 5          1     female
# 10         1     female
# 12         1     female
# 15         1     female
# 16         1     female
# ...      ...        ...
# 1011       1       male
# 1014       1     female
# 1019       1       male
# 1020       1       male
# 1023       1     female
#
# [526 rows x 2 columns]

# %%
df_grouped = pd.crosstab(df_filtered.target, df_filtered.sex_symbol)

# %%
df_grouped
# Out:
# sex_symbol  female  male
# target
# 0               86   413
# 1              226   300

# %%
# proporsi wanita sakit jantung
pf = df_grouped.female[1] / (df_grouped.female.sum())

# %%
pf
# Out:
# 0.7243589743589743

# %%
se_female = np.sqrt(pf * (1 - pf) / df_grouped.female.sum())

# %%
se_female
# Out:
# 0.02529714756803247

# %%
# confidence 
z_score = 1.96  # => 95%
upf = pf + (z_score * se_female)
lpf = pf - (z_score * se_female)
print("saya perkirakan wanita yang memiliki penyakit jantung dalam range", lpf, "-", upf)
# Out:
# saya perkirakan wanita yang memiliki penyakit jantung dalam range 0.6747765651256307 - 0.773941383592318

# %%
import statsmodels.api as sm
sm.stats.proportion_confint(df_grouped.female.sum() * pf, df_grouped.female.sum())
# Out:
# (0.6747774762140357, 0.773940472503913)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target sex_symbol
# 0   2     3       0       male
# 1   0     3       0       male
# 2   0     3       0       male
# 3   1     3       0       male
# 4   3     2       0     female

# %%
df_chol_agg = df.groupby("sex_symbol").agg({"chol": [np.mean, np.std, np.size]})
# Out:
# /var/folders/vv/qw6j8x591439gjsmtqqfmjw80000gn/T/ipykernel_29980/1415023524.py:1: FutureWarning: The provided callable <function mean at 0x1058462a0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df_chol_agg = df.groupby("sex_symbol").agg({"chol": [np.mean, np.std, np.size]})
# /var/folders/vv/qw6j8x591439gjsmtqqfmjw80000gn/T/ipykernel_29980/1415023524.py:1: FutureWarning: The provided callable <function std at 0x1058463e0> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   df_chol_agg = df.groupby("sex_symbol").agg({"chol": [np.mean, np.std, np.size]})

# %%
df_chol_female = df_chol_agg.loc["female","chol"]
df_chol_agg.head()
# Out:
#                   chol
#                   mean        std size
# sex_symbol
# female      261.455128  64.466781  312
# male        239.237027  43.155535  713

# %%
se_chol_female = df_chol_female["std"] / np.sqrt(df_chol_female["size"])

# %%
se_chol_female
# Out:
# 3.6497127678109655

# %%
z = 1.96 # => 95%
uc = df_chol_female["mean"] + (z * se_chol_female) 
lc = df_chol_female["mean"] - (z * se_chol_female)
print("nilai kolesterol wanita 95% berkisar pada", lc, "-", uc)
# Out:
# nilai kolesterol wanita 95% berkisar pada 254.30169118021874 - 268.6085652300377
