# %%
import numpy as np

# %%
arr = np.array([[1,2,3], [1, 4, 4], [7, 8, 9]])

# %%
arr_inv = np.linalg.inv(arr)

# %%
np.dot(arr_inv, arr)
# Out:
# array([[ 1.00000000e+00, -6.66133815e-16, -3.60822483e-16],
#        [ 9.02056208e-17,  1.00000000e+00,  3.53883589e-16],
#        [ 4.16333634e-17,  1.11022302e-16,  1.00000000e+00]])

# %%
np.dot(arr_inv, np.array([[10],[15],[20]]))
# Out:
# array([[-2.77777778],
#        [ 0.55555556],
#        [ 3.88888889]])

# %%
# pandas
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2

# %%
# pandas => menganalisis / loading data / cleansing data
# data source => csv, excel, json, sql

print(type(arr))

df = pd.DataFrame()
print(type(df))

df = pd.Series()
print(type(df))
# Out:
# <class 'numpy.ndarray'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
df_nba = pd.read_csv("nbaallelo.csv")

# %%
print(type(df_nba))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df_nba = pd.read_csv("https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv")

# %%
print(type(df_nba))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
len(df_nba)
# Out:
# 126314

# %%
df_nba.shape
# Out:
# (126314, 23)

# %%
df_nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  ...  opp_elo_n  \
# 0          1  194611010TRH   NBA        0     1947  ...  1306.7233
# 1          1  194611010TRH   NBA        1     1947  ...  1293.2767
# 2          2  194611020CHS   NBA        0     1947  ...  1297.0712
# 3          2  194611020CHS   NBA        1     1947  ...  1309.6521
# 4          3  194611020DTF   NBA        0     1947  ...  1320.3811
#
#    game_location  game_result  forecast notes
# 0              H            L  0.640065   NaN
# 1              A            W  0.359935   NaN
# 2              H            W  0.631101   NaN
# 3              A            L  0.368899   NaN
# 4              H            L  0.640065   NaN
#
# [5 rows x 23 columns]

# %%
df_nba.head
# Out:
# <bound method NDFrame.head of         gameorder       game_id lg_id  _iscopy  year_id  ...  opp_elo_n  \
# 0               1  194611010TRH   NBA        0     1947  ...  1306.7233
# 1               1  194611010TRH   NBA        1     1947  ...  1293.2767
# 2               2  194611020CHS   NBA        0     1947  ...  1297.0712
# 3               2  194611020CHS   NBA        1     1947  ...  1309.6521
# 4               3  194611020DTF   NBA        0     1947  ...  1320.3811
# ...           ...           ...   ...      ...      ...  ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  ...  1809.9791
# 126310      63156  201506140GSW   NBA        0     2015  ...  1700.7391
# 126311      63156  201506140GSW   NBA        1     2015  ...  1813.6349
# 126312      63157  201506170CLE   NBA        0     2015  ...  1822.2881
# 126313      63157  201506170CLE   NBA        1     2015  ...  1692.0859
#
#         game_location  game_result  forecast notes
# ...

# %%
df_nba.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  ...  opp_elo_n  \
# 126309      63155  201506110CLE   NBA        0     2015  ...  1809.9791
# 126310      63156  201506140GSW   NBA        0     2015  ...  1700.7391
# 126311      63156  201506140GSW   NBA        1     2015  ...  1813.6349
# 126312      63157  201506170CLE   NBA        0     2015  ...  1822.2881
# 126313      63157  201506170CLE   NBA        1     2015  ...  1692.0859
#
#         game_location  game_result  forecast notes
# 126309              H            L  0.546572   NaN
# 126310              H            W  0.765565   NaN
# 126311              A            L  0.234435   NaN
# 126312              H            L  0.481450   NaN
# 126313              A            W  0.518550   NaN
#
# [5 rows x 23 columns]

# %%
# pandas digunakan untuk menganalisis
# pandas bisa mendisplay data frame dalam bentuk data table
# pandas bisa cleansing

# %%
pd.set_option("display.max.columns", None)

# %%
df_nba.tail(2)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126312         102            1     CLE  Cavaliers   97  1700.7391  1692.0859
# 126313         103            1     GSW   Warriors  105  1813.6349  1822.2881
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 126312  59.290245    GSW   Warriors      105  1813.6349  1822.2881
# 126313  68.519516    CLE  Cavaliers       97  1700.7391  1692.0859
#
#        game_location game_result  forecast notes
# 126312             H           L   0.48145   NaN
# 126313             A           W   0.51855   NaN

# %%
df_nba.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes
# 0   NaN
# 1   NaN

# %%
df_nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df_nba.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %%
df_nba["pts"][0]
# Out:
# 66

# %%
df_nba["opp_elo_i"].min()
# Out:
# 1091.6445

# %%
df_nba["opp_elo_i"].value_counts()
# Out:
# opp_elo_i
# 1300.0000    42
# 1467.0219     3
# 1501.8104     3
# 1372.6279     3
# 1404.3896     3
#              ..
# 1563.2418     1
# 1472.0475     1
# 1402.4943     1
# 1638.4840     1
# 1700.7391     1
# Name: count, Length: 123947, dtype: int64

# %%
# Matlab

# %%
df_nba.loc[df_nba["opp_elo_i"] == 1300.0000, "team_id"]
# Out:
# 0        TRH
# 1        NYK
# 3        NYK
# 4        DTF
# 5        WSC
# 6        BOS
# 7        PRO
# 8        PIT
# 9        STB
# 10       TRH
# 18       PIT
# 1894     DNN
# 10414    NYK
# 14297    STL
# 15161    SFW
# 15162    OAK
# 15163    ANA
# 15166    STL
# 15168    KEN
# 15169    INA
# 15172    ANA
# 15175    ANA
# 15185    DNR
# 15199    HSM
# 15230    KEN
# 15234    NJA
# 15235    PTP
# 17154    CHI
# 17163    SEA
# 21554    BUF
# 21555    CLE
# 21577    CLE
# 26541    DNR
# 31291    NYK
# 43664    SAS
# 59750    CLE
# 59776    LAC
# 61943    SEA
# 61956    NJN
# 76103    POR
# 76109    NJN
# 97919    WAS
# Name: team_id, dtype: object

# %%
df_nba.loc[df_nba["year_id"] > 2013]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 121054      60528  201310290IND   NBA        1     2014  10/29/2013
# 121055      60528  201310290IND   NBA        0     2014  10/29/2013
# 121056      60529  201310290LAL   NBA        0     2014  10/29/2013
# 121057      60529  201310290LAL   NBA        1     2014  10/29/2013
# 121058      60530  201310290MIA   NBA        1     2014  10/29/2013
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# ...

# %%
# coba cari sum pts dari CLE dengan tahun 2015
df_nba.loc[df_nba["team_id"] == "CLE"].loc[df_nba["year_id"] == 2015, "pts"].sum()
# Out:
# 10437

# %%
df_nba.loc[df_nba["team_id"] == "CLE"].loc[df_nba["year_id"] == 2015, "pts"].max()
# Out:
# 129

# %%
df_nba.loc[df_nba["team_id"] == "CLE"].loc[df_nba["year_id"] == 2015, "pts"].min()
# Out:
# 78

# %%
df_nba.loc[df_nba["team_id"] == "CLE"].loc[df_nba["year_id"] == 2015, "pts"].agg(("min", "max"))
# Out:
# min     78
# max    129
# Name: pts, dtype: int64

# %%
series = pd.Series([1000, 2000, 3000, 4000], index= ["2015", "2016", "2017", "2018"])

# %%
series
# Out:
# 2015    1000
# 2016    2000
# 2017    3000
# 2018    4000
# dtype: int64

# %%
salary = pd.Series({"June":2000, "July":2000})

# %%
salary
# Out:
# June    2000
# July    2000
# dtype: int64

# %%
salary.keys()
# Out:
# Index(['June', 'July'], dtype='object')

# %%
df_1 = pd.DataFrame({
    "salary": salary
})

# %%
df_1
# Out:
#       salary
# June    2000
# July    2000

# %%
df_1["salary"]["June"]
# Out:
# 2000

# %%
df_1.index
# Out:
# Index(['June', 'July'], dtype='object')

# %%
df_1.values
# Out:
# array([[2000],
#        [2000]])

# %%
df_1.axes
# Out:
# [Index(['June', 'July'], dtype='object'), Index(['salary'], dtype='object')]

# %%
df_nba.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
df_nba.keys()
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#       dtype='object')

# %%
df_1.keys()
# Out:
# Index(['salary'], dtype='object')

# %%
salary[0]
# Out:
# /var/folders/vv/qw6j8x591439gjsmtqqfmjw80000gn/T/ipykernel_34432/582786413.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   salary[0]
# 2000

# %%
salary.iloc[0]
# Out:
# 2000

# %%
salary["June"]
# Out:
# 2000

# %%
colors = pd.Series(    ["red", "purple", "blue", "green", "yellow"],    index=[1, 2, 3, 5, 8])

# %%
colors.iloc[1]
# Out:
# 'purple'

# %%
colors.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/py_data/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 colors.loc[0]
#
# ...

# %%
colors.iloc[:]
# Out:
# 1       red
# 2    purple
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
colors.iloc[:4]
# Out:
# 1       red
# 2    purple
# 3      blue
# 5     green
# dtype: object

# %%
colors.iloc[-1]
# Out:
# 'yellow'

# %%
salary["June"]
# Out:
# 2000

# %%
salary.June
# Out:
# 2000

# %%
salary.shape
# Out:
# (2,)

# %%
df_1.shape
# Out:
# (2, 1)

# %%
# iloc => index number location (dimulai dari 0)
# loc => index name location (berdasarkan index attribute)

df_nba.loc[1000:2000, ["team_id", "pts"]]
# Out:
#      team_id  pts
# 1000     WSC   85
# 1001     BLB   72
# 1002     CHS   97
# 1003     BOS   77
# 1004     NYK   71
# ...      ...  ...
# 1996     BOS   76
# 1997     BLB   81
# 1998     CHS   77
# 1999     WSC   63
# 2000     AND   83
#
# [1001 rows x 2 columns]

# %%
# Query data frame
df_nba.loc[df_nba["team_id"] == "CLE", ["team_id", "pts"]]
# Out:
#        team_id  pts
# 21555      CLE   92
# 21577      CLE  112
# 21598      CLE  108
# 21625      CLE   98
# 21654      CLE  110
# ...        ...  ...
# 126304     CLE   95
# 126307     CLE   96
# 126309     CLE   82
# 126311     CLE   91
# 126312     CLE   97
#
# [3810 rows x 2 columns]

# %%
df_nba.loc[df_nba["fran_id"].str.endswith("ers")]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 16              9  194611050DTF   NBA        1     1947  11/5/1946
# 20             11  194611070PRO   NBA        0     1947  11/7/1946
# 22             12  194611070STB   NBA        0     1947  11/7/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts      elo_i  \
# 7                1            0     PRO  Steamrollers   59  1300.0000
# ...

# %%
# Query fran_id berakhiran ers
# dan tahun > 2014
df_nba.loc[df_nba["fran_id"].str.endswith("ers")].loc[df_nba["year_id"]>2014]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 123693      61847  201410280LAL   NBA        0     2015  10/28/2014
# 123704      61853  201410290IND   NBA        0     2015  10/29/2014
# 123705      61853  201410290IND   NBA        1     2015  10/29/2014
# 123713      61857  201410290PHO   NBA        1     2015  10/29/2014
# 123715      61858  201410290POR   NBA        0     2015  10/29/2014
# ...           ...           ...   ...      ...      ...         ...
# 126304      63153  201506070GSW   NBA        1     2015    6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015    6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts      elo_i  \
# 123693           1            0     LAL        Lakers   90  1421.9985
# ...

# %%
df_nba[
    (df_nba["fran_id"].str.endswith("ers")) &
    (df_nba["year_id"]>2014)
].describe()
# Out:
#           gameorder     _iscopy  year_id  seasongame  is_playoffs         pts  \
# count    531.000000  531.000000    531.0  531.000000   531.000000  531.000000
# mean   62509.062147    0.500942   2015.0   45.096045     0.073446  100.171375
# std      382.218087    0.500471      0.0   26.185698     0.261114   11.652954
# min    61847.000000    0.000000   2015.0    1.000000     0.000000   70.000000
# 25%    62182.500000    0.000000   2015.0   23.000000     0.000000   92.000000
# 50%    62505.000000    1.000000   2015.0   45.000000     0.000000  100.000000
# 75%    62839.000000    1.000000   2015.0   67.000000     0.000000  107.000000
# max    63157.000000    1.000000   2015.0  102.000000     1.000000  130.000000
#
#              elo_i        elo_n   win_equiv     opp_pts    opp_elo_i  \
# count   531.000000   531.000000  531.000000  531.000000   531.000000
# mean   1504.368786  1504.508868   41.155095  100.086629  1515.568082
# ...

# %%
# sum pts dari setiap fran_id 
# pada tahun >= 2014
df_nba.loc[df_nba["year_id"] >= 2014].groupby("fran_id")["pts"].sum()
# Out:
# fran_id
# Bucks           16383
# Bulls           17547
# Cavaliers       18491
# Celtics         16583
# Clippers        20524
# Grizzlies       17665
# Hawks           18906
# Heat            18089
# Hornets         16031
# Jazz            15592
# Kings           16551
# Knicks          15619
# Lakers          16515
# Magic           15761
# Mavericks       18483
# Nets            17841
# Nuggets         16879
# Pacers          17654
# Pelicans        16727
# Pistons         16363
# Raptors         17890
# Rockets         19862
# Sixers          15697
# Spurs           20270
# Suns            17026
# Thunder         19176
# Timberwolves    16784
# Trailblazers    18798
# Warriors        20479
# Wizards         18339
# Name: pts, dtype: int64

# %%
# hitung jumlah L W dari setiap tim
# pada tahun >= 2014
df_nba.loc[df_nba["year_id"] >= 2014].groupby(["fran_id", "game_result"])["game_id"].count()
# Out:
# fran_id       game_result
# Bucks         L              112
#               W               58
# Bulls         L               76
#               W              105
# Cavaliers     L               84
#               W              100
# Celtics       L              103
#               W               65
# Clippers      L               65
#               W              126
# Grizzlies     L               68
#               W              114
# Hawks         L               78
#               W              109
# Heat          L               80
#               W              104
# Hornets       L               92
#               W               76
# Jazz          L              101
#               W               63
# Kings         L              107
#               W               57
# Knicks        L              110
#               W               54
# Lakers        L              116
#               W               48
# Magic         L              116
# ...

# %%
# hitung jumlah L W dari setiap tim
# pada tahun >= 2014
# dan group sesuai dengan game H A
df_nba.loc[df_nba["year_id"] >= 2014].groupby(["fran_id", "game_result", "game_location"])["game_id"].count()
# Out:
# fran_id   game_result  game_location
# Bucks     L            A                61
#                        H                51
#           W            A                24
#                        H                33
#                        N                 1
#                                         ..
# Warriors  W            H                77
# Wizards   L            A                46
#                        H                37
#           W            A                47
#                        H                55
# Name: game_id, Length: 126, dtype: int64

# %%
df_nba["pts"]
# Out:
# 0          66
# 1          68
# 2          63
# 3          47
# 4          33
#          ...
# 126309     82
# 126310    104
# 126311     91
# 126312     97
# 126313    105
# Name: pts, Length: 126314, dtype: int64

# %%
# manipulating / menambahkan column
df_nba["diff"] = df_nba["pts"] - df_nba["opp_pts"]

# %%
df_nba.shape
# Out:
# (126314, 24)

# %%
df_nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df_nba.loc[df_nba["diff"] > 0]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 5               3  194611020DTF   NBA        1     1947  11/2/1946
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts      elo_i  \
# 1                1            0     NYK        Knicks   68  1300.0000
# ...

# %%
df_nba.rename(columns={"fran_id":"team_name"})
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id  team_name  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
df_nba_2 = df_nba.drop(["notes"], axis=1)

# %%
df_nba.drop([1], axis=0)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# 5               3  194611020DTF   NBA        1     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
df_nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df_nba_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df_nba["date_game"] = pd.to_datetime(df_nba["date_game"])

# %%
df_nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
pd.Categorical(df_nba["game_location"])
# Out:
# ['H', 'A', 'H', 'A', 'H', ..., 'H', 'H', 'A', 'H', 'A']
# Length: 126314
# Categories (3, object): ['A', 'H', 'N']

# %%
df_nba.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5424 entries, 930 to 124863
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gameorder      5424 non-null   int64
#  1   game_id        5424 non-null   object
#  2   lg_id          5424 non-null   object
#  3   _iscopy        5424 non-null   int64
#  4   year_id        5424 non-null   int64
#  5   date_game      5424 non-null   datetime64[ns]
#  6   seasongame     5424 non-null   int64
#  7   is_playoffs    5424 non-null   int64
#  8   team_id        5424 non-null   object
#  9   fran_id        5424 non-null   object
#  10  pts            5424 non-null   int64
#  11  elo_i          5424 non-null   float64
#  12  elo_n          5424 non-null   float64
#  13  win_equiv      5424 non-null   float64
#  14  opp_id         5424 non-null   object
#  15  opp_fran       5424 non-null   object
#  16  opp_pts        5424 non-null   int64
# ...

# %%
df_nba["notes"].fillna(value="Missing Notes")
# Out:
# 0         Missing Notes
# 1         Missing Notes
# 2         Missing Notes
# 3         Missing Notes
# 4         Missing Notes
#               ...
# 126309    Missing Notes
# 126310    Missing Notes
# 126311    Missing Notes
# 126312    Missing Notes
# 126313    Missing Notes
# Name: notes, Length: 126314, dtype: object

# %%
df_nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df_nba[(df_nba["pts"] > df_nba["opp_pts"]) & (df_nba["game_result"] != "W")]
# Out:
# Empty DataFrame
# Columns: [gameorder, game_id, lg_id, _iscopy, year_id, date_game, seasongame, is_playoffs, team_id, fran_id, pts, elo_i, elo_n, win_equiv, opp_id, opp_fran, opp_pts, opp_elo_i, opp_elo_n, game_location, game_result, forecast, notes, diff]
# Index: []

# %%
# combine
df_2 = pd.DataFrame({
    "Indonesia" : 1000,
    "Singapore" : 2000
}, index=[2015, 2014])

# %%
df_2
# Out:
#       Indonesia  Singapore
# 2015       1000       2000
# 2014       1000       2000

# %%
df_3 = pd.DataFrame({
    "Indonesia" : 1500,
    "Singapore" : 4000
}, index=[2017, 2016])

# %%
df_4 = pd.concat([df_2, df_3], axis=0, sort=False)

# %%
df_4
# Out:
#       Indonesia  Singapore
# 2015       1000       2000
# 2014       1000       2000
# 2017       1500       4000
# 2016       1500       4000

# %%
df_5 = pd.DataFrame({
    "Thailand" : 1000,
    "Vietnam" : 2000
}, index=[2015, 2014, 2017, 2016])

# %%
pd.concat([df_4, df_5], axis=1)
# Out:
#       Indonesia  Singapore  Thailand  Vietnam
# 2015       1000       2000      1000     2000
# 2014       1000       2000      1000     2000
# 2017       1500       4000      1000     2000
# 2016       1500       4000      1000     2000
